# %% [markdown]
# #import necessary libraries and functions

# %%
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential

from sklearn.model_selection import train_test_split

# %% [markdown]
# #Load the train and test dataset

# %%
data_1 = pd.read_csv('train.csv')
data_1.head()
# Out:
#   image_names  class
# 0    0001.jpg      1
# 1    0002.jpg      1
# 2    0003.jpg      1
# 3    0004.jpg      1
# 4    0005.jpg      1

# %%
data_2 = pd.read_csv('test.csv')
data_2.head()
# Out:
#   image_names
# 0    0001.jpg
# 1    0002.jpg
# 2    0003.jpg
# 3    0004.jpg
# 4    0005.jpg

# %% [markdown]
# #create random number generator

# %%
seed = 42
rng = np.random.RandomState(seed)

# %% [markdown]
# #distribution of classes in the dataset

# %%
data_1['class'].value_counts()
# Out:
# class
# 1    2440
# 0     962
# Name: count, dtype: int64

# %% [markdown]
# #load images and store it in numpy array

# %%
# empty list to store the images
X = []
# iterating over each image
print(data_1.image_names)
for img_name in data_1.image_names:
    # loading the image using its name
    img = plt.imread('images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data_1['class'].values
#y = data_1.class.values

# %% [markdown]
# #shape of the image

# %%
X.shape
# Out:
# (3402, 224, 224, 3)

# %% [markdown]
# #visualizing images

# %%
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*500])
    ax[i].axis('off')

# %% [markdown]
# #Pre-processing the dat

# %% [markdown]
# #converting 3 dimensional image to 1 dimensional image

# %%
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (3402, 150528)

# %% [markdown]
# #minimum and maximum pixel values of images

# %%
X.min(), X.max()
# Out:
# (0, 255)

# %% [markdown]
# #minimum and maximum pixel values of images after normalizing

# %%
X.min(), X.max()
# Out:
# (0, 255)

# %% [markdown]
# #Creating training and validation set

# %% [markdown]
# #Creating a training and validation set

# %%
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %% [markdown]
# #Shape of training and validation set

# %%
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((2381, 150528), (2381,)), ((1021, 150528), (1021,)))

# %% [markdown]
# #Defining the model architecture

# %% [markdown]
# #Defining the architecture of the model

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# C:\Users\7490\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# #Summary of the model

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │    15,052,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,053,001 (57.42 MB)
#  Trainable params: 15,053,001 (57.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Compiling the model

# %%
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# #Training the model

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.6879 - loss: 0.6344 - val_accuracy: 0.7169 - val_loss: 0.5944
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7217 - loss: 0.5914 - val_accuracy: 0.7169 - val_loss: 0.5953
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7148 - loss: 0.5981 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7191 - loss: 0.5941 - val_accuracy: 0.7169 - val_loss: 0.5950
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7080 - loss: 0.6039 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7020 - loss: 0.6100 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7140 - loss: 0.5991 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.7108 - loss: 0.6018 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.7068 - loss: 0.6057 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.7116 - loss: 0.6012 - val_accuracy: 0.7169 - val_loss: 0.5956
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.7273 - loss: 0.5864 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7091 - loss: 0.6033 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7153 - loss: 0.5980 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7234 - loss: 0.5901 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.7156 - loss: 0.5976 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.7246 - loss: 0.5892 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.7217 - loss: 0.5916 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.7202 - loss: 0.5934 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7102 - loss: 0.6023 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.7247 - loss: 0.5887 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.7088 - loss: 0.6038 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.7145 - loss: 0.5984 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.7143 - loss: 0.5985 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.7250 - loss: 0.5884 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7102 - loss: 0.6024 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.7094 - loss: 0.6031 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7154 - loss: 0.5976 - val_accuracy: 0.7169 - val_loss: 0.5956
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.7276 - loss: 0.5860 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.7159 - loss: 0.5972 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7002 - loss: 0.6116 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.7232 - loss: 0.5904 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.7186 - loss: 0.5946 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.7195 - loss: 0.5938 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7063 - loss: 0.6064 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.7097 - loss: 0.6032 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.7205 - loss: 0.5927 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.7250 - loss: 0.5885 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.7152 - loss: 0.5978 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7183 - loss: 0.5949 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.7131 - loss: 0.5999 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.7043 - loss: 0.6075 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.7068 - loss: 0.6058 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7223 - loss: 0.5911 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.7305 - loss: 0.5837 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.7196 - loss: 0.5935 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.7222 - loss: 0.5913 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.7195 - loss: 0.5936 - val_accuracy: 0.7169 - val_loss: 0.5955
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.7169 - loss: 0.5960 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.7150 - loss: 0.5978 - val_accuracy: 0.7169 - val_loss: 0.5954
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.7121 - loss: 0.6007 - val_accuracy: 0.7169 - val_loss: 0.5954

# %% [markdown]
# #Evaluating model performance

# %% [markdown]
# #Getting predictions in the form of class as well as probabilities

# %%
predictions_probabilities = model.predict(X_valid)
predictions = predictions_probabilities.argmax(axis=1)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %% [markdown]
# #Accuracy on validation set

# %%
from sklearn.metrics import accuracy_score
print('Accuracy on validation set:', accuracy_score(y_valid, predictions)*100, '%')
# Out:
# Accuracy on validation set: 28.305582761998043 %

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# #Summarize history for accuracy

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# pull out the original images from the data which correspond to the validation data
_, valid_Gender, _, valid_y = train_test_split(data_1.image_names.values, y, test_size=0.3, random_state=seed)

# get a random index to plot image randomly
index = rng.choice(range(len(valid_Gender)))

# get the corresponding image name and probability
img_name = valid_Gender[index]
prob = (predictions_probabilities * 100).astype(int)[index]

# read the image
img = plt.imread('images/' + img_name)

# print probability and actual class
print('Model is', prob , '% sure that it is female')
print('And actual class is ', valid_y[index])

# plot image
plt.imshow(img)
# Out:
# Model is [71] % sure that it is female
# And actual class is  0

# %% [markdown]
# #Changing activation function of hidden layer

# %% [markdown]
# #Using relu as activation function in hidden layer

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# C:\Users\7490\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# #Compiling the model

# %%
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# #Summary of the model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 100)            │    15,052,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,053,001 (57.42 MB)
#  Trainable params: 15,053,001 (57.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training the model for 50 epochs

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5946 - loss: 11337221.0000 - val_accuracy: 0.7160 - val_loss: 0.6872
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7126 - loss: 0.6852 - val_accuracy: 0.7160 - val_loss: 0.6794
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.7179 - loss: 0.6760 - val_accuracy: 0.7160 - val_loss: 0.6722
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.7227 - loss: 0.6684 - val_accuracy: 0.7160 - val_loss: 0.6656
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7199 - loss: 0.6623 - val_accuracy: 0.7160 - val_loss: 0.6597
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7180 - loss: 0.6567 - val_accuracy: 0.7160 - val_loss: 0.6542
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.7194 - loss: 0.6511 - val_accuracy: 0.7160 - val_loss: 0.6494
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.7102 - loss: 0.6036 - val_accuracy: 0.7160 - val_loss: 0.5996
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.7177 - loss: 0.5977 - val_accuracy: 0.7160 - val_loss: 0.5994
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7198 - loss: 0.5958 - val_accuracy: 0.7160 - val_loss: 0.5993
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.7148 - loss: 0.5996 - val_accuracy: 0.7160 - val_loss: 0.5991
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.7182 - loss: 0.5967 - val_accuracy: 0.7160 - val_loss: 0.5989
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.6972 - loss: 0.6133 - val_accuracy: 0.7160 - val_loss: 0.5988
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.7231 - loss: 0.5925 - val_accuracy: 0.7160 - val_loss: 0.5987
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.7212 - loss: 0.5938 - val_accuracy: 0.7160 - val_loss: 0.5985

# %% [markdown]
# #Accuracy on validation set

# %%
import numpy as np

raw_predictions = model.predict(X_valid)
predicted_classes = np.argmax(raw_predictions, axis=1)

accuracy = np.mean(predicted_classes == y_valid)
print('Accuracy on validation set:', accuracy, '%')
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Accuracy on validation set: 0.28305582761998044 %

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# #Increase hidden neurons

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(1024, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# #Compiling the model

# %%
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# #Model summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 1024)           │   154,141,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,142,721 (588.01 MB)
#  Trainable params: 154,142,721 (588.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 14/19 ━━━━━━━━━━━━━━━━━━━━ 2s 599ms/step - accuracy: 0.6604 - loss: 0.7507

# %% [markdown]
# #Accuracy on validation set

# %%
import numpy as np
from sklearn.metrics import accuracy_score

y_pred_probabilities = model.predict(X_valid)
y_pred_classes =np.argmax(y_pred_probabilities, axis=1)
accuracy = accuracy_score(y_valid, y_pred_classes)
print('Accuracy on validation set:', accuracy, '%')

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# #Increasing hidden layers

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# #Compiling the model

# %%
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# #Model summary

# %%
model.summary()

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))

# %% [markdown]
# #ccuracy on validation set

# %%
from sklearn.metrics import accuracy_score
import numpy as np

predictions = model.predict(X_valid)
binary_predictions = np.where(predictions >= 0.5, 1, 0)
accuracy = accuracy_score(y_valid, binary_predictions)
print('Accuracy on validation set:', accuracy*100)

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# #Increase number of epochs

# %%
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# #Model summary

# %%
model.summary()

# %%
model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))

# %% [markdown]
# #Accuracy on validation set

# %%
from sklearn.metrics import accuracy_score


predictions = model.predict(X_valid)


binary_predictions = (predictions >= 0.5).astype(int)


accuracy = accuracy_score(y_valid, binary_predictions)

print('Accuracy on validation set:', accuracy)

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# #Changing the optimizer

# %% [markdown]
# #Importing adam optimizer from keras optimizer module

# %%
from keras.optimizers import Adam

# %% [markdown]
# #Defining the adam optimizer and setting the learning rate as 10^-5

# %%
adam = adam = Adam(learning_rate=1e-5)

# %% [markdown]
# #Change optimizer

# %%
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# #Model summary

# %%
model.summary()

# %%
model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))

# %% [markdown]
# #Accuracy on validation set

# %%
print('Accuracy on validation set:', accuracy_score(y_valid, model.predict_classes(X_valid)[:, 0]), '%')

# %% [markdown]
# #Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# #Summarize history for accuracy

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
